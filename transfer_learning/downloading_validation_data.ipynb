# %%
import time, datetime, json, requests, shutil, threading

exitFlag = 0

class my_thread (threading.Thread):
    def __init__(self, thread_id, thread_nm, set_str, lower, upper):
        threading.Thread.__init__(self)
        self.thread_id = thread_id
        self.thread_nm = thread_nm
        self.set_str = set_str
        self.lower = lower
        self.upper = upper

    def run(self):
        print ("Starting " + self.thread_nm)
        download(self.thread_nm, self.set_str, self.lower, self.upper)
        print ("Exiting " + self.thread_nm)

def download(thread_nm, set_str, lower, upper):
    data = json.load(open(set_str + '.json'))

    t = time.time()
    
    for i in range(lower, upper):
        if exitFlag:
            thread_nm.exit()

        response = requests.get(data['images'][i]['url'], timeout = 5, stream = True)
        
        with open('data/'+set_str+'_images/'+str(data['images'][i]['imageId'])+'.jpeg', 'wb') as out_file:
            shutil.copyfileobj(response.raw, out_file)
        
        if i % 100 == 0:
            t_diff = round(time.time() - t, 2)
            t = time.time()
            print('{0} - {1} - {2} - {3}s - {4}'.format(str(datetime.datetime.now()), thread_nm, set_str, t_diff, i))
        
        del response

# %%
thread1 = my_thread(1, 'Thread-1', 'validation', 0, 2000)
thread2 = my_thread(2, 'Thread-2', 'validation', 2000, 4000)
thread3 = my_thread(3, 'Thread-3', 'validation', 4000, 6000)
thread4 = my_thread(4, 'Thread-4', 'validation', 6000, 8000)
thread5 = my_thread(5, 'Thread-5', 'validation', 8000, 10000)
thread1.start()
thread2.start()
thread3.start()
thread4.start()
thread5.start()
thread1.join()
thread2.join()
thread3.join()
thread4.join()
thread5.join()
print ("Exiting Main Thread.")
# Out:
# Starting Thread-1
# Starting Thread-2
# Starting Thread-3
# Starting Thread-4
# Starting Thread-5
# 2018-07-20 01:25:56.872632 - Thread-2 - validation - 0.73s - 2000
# 2018-07-20 01:25:56.878240 - Thread-5 - validation - 0.74s - 8000
# 2018-07-20 01:25:56.880067 - Thread-4 - validation - 0.78s - 6000
# 2018-07-20 01:25:56.890251 - Thread-1 - validation - 0.75s - 0
# 2018-07-20 01:25:56.904373 - Thread-3 - validation - 0.76s - 4000
# 2018-07-20 01:26:17.277951 - Thread-5 - validation - 20.4s - 8100
# 2018-07-20 01:26:17.493102 - Thread-1 - validation - 20.6s - 100
# 2018-07-20 01:26:17.538185 - Thread-4 - validation - 20.66s - 6100
# 2018-07-20 01:26:18.010781 - Thread-3 - validation - 21.11s - 4100
# 2018-07-20 01:26:22.903765 - Thread-2 - validation - 26.03s - 2100
# 2018-07-20 01:26:37.540740 - Thread-5 - validation - 20.26s - 8200
# 2018-07-20 01:26:37.883676 - Thread-4 - validation - 20.35s - 6200
# 2018-07-20 01:26:58.409915 - Thread-4 - validation - 20.53s - 6300
# 2018-07-20 01:26:58.527383 - Thread-5 - validation - 20.99s - 8300
# 2018-07-20 01:26:59.818295 - Thread-2 - validation - 36.91s - 2200
# 2018-07-20 01:27:00.751975 - Thread-1 - validation - 43.26s - 200
# 2018-07-20 01:27:13.200083 - Thread-3 - validation - 55.19s - 4200
# 2018-07-20 01:27:18.391319 - Thread-4 - validation - 19.98s - 6400
# 2018-07-20 01:27:18.403002 - Thread-5 - validation - 19.88s - 8400
# 2018-07-20 01:27:37.929191 - Thread-1 - validation - 37.18s - 300
# 2018-07-20 01:27:41.674098 - Thread-2 - validation - 41.86s - 2300
# 2018-07-20 01:28:00.729257 - Thread-4 - validation - 42.34s - 6500
# 2018-07-20 01:28:01.931100 - Thread-3 - validation - 48.73s - 4300
# 2018-07-20 01:28:02.483248 - Thread-5 - validation - 44.08s - 8500
# 2018-07-20 01:28:06.655550 - Thread-1 - validation - 28.73s - 400
# 2018-07-20 01:28:12.842974 - Thread-2 - validation - 31.17s - 2400
# 2018-07-20 01:28:22.566961 - Thread-4 - validation - 21.84s - 6600
# 2018-07-20 01:28:23.619078 - Thread-5 - validation - 21.14s - 8600
# 2018-07-20 01:28:31.118368 - Thread-1 - validation - 24.46s - 500
# 2018-07-20 01:28:34.527086 - Thread-2 - validation - 21.68s - 2500
# 2018-07-20 01:28:44.198826 - Thread-4 - validation - 21.63s - 6700
# 2018-07-20 01:28:44.755445 - Thread-5 - validation - 21.14s - 8700
# 2018-07-20 01:28:55.113186 - Thread-2 - validation - 20.59s - 2600
# 2018-07-20 01:28:59.861785 - Thread-3 - validation - 57.93s - 4400
# 2018-07-20 01:29:04.811917 - Thread-4 - validation - 20.61s - 6800
# 2018-07-20 01:29:06.067502 - Thread-5 - validation - 21.31s - 8800
# 2018-07-20 01:29:10.895752 - Thread-1 - validation - 39.78s - 600
# 2018-07-20 01:29:18.952045 - Thread-2 - validation - 23.84s - 2700
# 2018-07-20 01:29:27.303347 - Thread-4 - validation - 22.49s - 6900
# 2018-07-20 01:29:28.629180 - Thread-5 - validation - 22.56s - 8900
# 2018-07-20 01:29:48.661691 - Thread-4 - validation - 21.36s - 7000
# 2018-07-20 01:29:50.142873 - Thread-5 - validation - 21.51s - 9000
# 2018-07-20 01:29:50.213719 - Thread-1 - validation - 39.32s - 700
# 2018-07-20 01:29:57.696135 - Thread-3 - validation - 57.83s - 4500
# 2018-07-20 01:30:00.392607 - Thread-2 - validation - 41.44s - 2800
# 2018-07-20 01:30:23.904184 - Thread-5 - validation - 33.76s - 9100
# 2018-07-20 01:30:29.982586 - Thread-4 - validation - 41.32s - 7100
# 2018-07-20 01:30:33.251247 - Thread-1 - validation - 43.04s - 800
# 2018-07-20 01:30:40.579317 - Thread-2 - validation - 40.19s - 2900
# 2018-07-20 01:30:45.138093 - Thread-3 - validation - 47.44s - 4600
# 2018-07-20 01:30:49.722163 - Thread-5 - validation - 25.82s - 9200
# 2018-07-20 01:30:54.290535 - Thread-4 - validation - 24.31s - 7200
# 2018-07-20 01:31:03.946993 - Thread-1 - validation - 30.7s - 900
# 2018-07-20 01:31:13.810614 - Thread-5 - validation - 24.09s - 9300
# 2018-07-20 01:31:21.239987 - Thread-2 - validation - 40.66s - 3000
# 2018-07-20 01:31:27.939974 - Thread-4 - validation - 33.65s - 7300
# 2018-07-20 01:31:37.635690 - Thread-3 - validation - 52.5s - 4700
# 2018-07-20 01:31:47.225746 - Thread-1 - validation - 43.28s - 1000
# 2018-07-20 01:31:53.126321 - Thread-5 - validation - 39.32s - 9400
# 2018-07-20 01:31:59.428388 - Thread-2 - validation - 38.19s - 3100
# 2018-07-20 01:32:14.767690 - Thread-4 - validation - 46.83s - 7400
# 2018-07-20 01:32:28.110333 - Thread-1 - validation - 40.88s - 1100
# 2018-07-20 01:32:28.909314 - Thread-3 - validation - 51.27s - 4800
# 2018-07-20 01:32:30.317245 - Thread-2 - validation - 30.89s - 3200
# 2018-07-20 01:32:32.954478 - Thread-5 - validation - 39.83s - 9500
# 2018-07-20 01:32:57.564430 - Thread-4 - validation - 42.8s - 7500
# 2018-07-20 01:33:00.260485 - Thread-1 - validation - 32.15s - 1200
# 2018-07-20 01:33:07.682736 - Thread-2 - validation - 37.37s - 3300
# 2018-07-20 01:33:10.591657 - Thread-5 - validation - 37.64s - 9600
# 2018-07-20 01:33:19.637067 - Thread-3 - validation - 50.73s - 4900
# 2018-07-20 01:33:22.244441 - Thread-4 - validation - 24.68s - 7600
# 2018-07-20 01:33:30.443588 - Thread-1 - validation - 30.18s - 1300
# 2018-07-20 01:33:36.249151 - Thread-2 - validation - 28.57s - 3400
# 2018-07-20 01:33:42.896043 - Thread-5 - validation - 32.3s - 9700
# 2018-07-20 01:34:02.642797 - Thread-1 - validation - 32.2s - 1400
# 2018-07-20 01:34:08.009016 - Thread-3 - validation - 48.37s - 5000
# 2018-07-20 01:34:08.578175 - Thread-4 - validation - 46.33s - 7700
# 2018-07-20 01:34:15.695179 - Thread-2 - validation - 39.45s - 3500
# 2018-07-20 01:34:29.291792 - Thread-5 - validation - 46.4s - 9800
# 2018-07-20 01:34:35.967122 - Thread-1 - validation - 33.32s - 1500
# 2018-07-20 01:34:53.051314 - Thread-4 - validation - 44.47s - 7800
# 2018-07-20 01:34:56.079676 - Thread-2 - validation - 40.38s - 3600
# 2018-07-20 01:34:56.684351 - Thread-3 - validation - 48.68s - 5100
# Exception in thread Thread-8:
# Traceback (most recent call last):
#   File "/home/parmeet/anaconda3/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "<ipython-input-1-4fbe285bb282>", line 16, in run
#     download(self.thread_nm, self.set_str, self.lower, self.upper)
#   File "<ipython-input-1-4fbe285bb282>", line 28, in download
#     response = requests.get(data['images'][i]['url'], timeout = 5, stream = True)
# IndexError: list index out of range
# 2018-07-20 01:35:21.460051 - Thread-1 - validation - 45.49s - 1600
# 2018-07-20 01:35:31.857724 - Thread-2 - validation - 35.78s - 3700
# 2018-07-20 01:35:43.117360 - Thread-4 - validation - 50.07s - 7900
# 2018-07-20 01:35:47.990285 - Thread-1 - validation - 26.53s - 1700
# 2018-07-20 01:35:48.646643 - Thread-3 - validation - 51.96s - 5200
# 2018-07-20 01:36:06.330338 - Thread-2 - validation - 34.47s - 3800
# Exiting Thread-4
# 2018-07-20 01:36:33.724808 - Thread-1 - validation - 45.73s - 1800
# 2018-07-20 01:36:35.880058 - Thread-3 - validation - 47.23s - 5300
# 2018-07-20 01:36:39.116968 - Thread-2 - validation - 32.79s - 3900
# 2018-07-20 01:37:00.209131 - Thread-1 - validation - 26.48s - 1900
# Exiting Thread-2
# Exiting Thread-1
# 2018-07-20 01:37:34.774089 - Thread-3 - validation - 58.89s - 5400
# 2018-07-20 01:38:38.918777 - Thread-3 - validation - 64.14s - 5500
# 2018-07-20 01:39:41.428651 - Thread-3 - validation - 62.51s - 5600
# 2018-07-20 01:40:47.598858 - Thread-3 - validation - 66.17s - 5700
# 2018-07-20 01:41:48.545503 - Thread-3 - validation - 60.95s - 5800
# 2018-07-20 01:42:51.656519 - Thread-3 - validation - 63.11s - 5900
# Exiting Thread-3
# Exiting Main Thread.

# %%
with open('validation.json') as validation_json:
    validation_data = json.load(validation_json)
num_validation_images = len(validation_data['images'])

# %%
num_validation_images
# Out:
# 9897
