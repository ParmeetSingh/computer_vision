# %%
import time, datetime, json, requests, shutil, threading

exitFlag = 0

class my_thread (threading.Thread):
    def __init__(self, thread_id, thread_nm, set_str, lower, upper):
        threading.Thread.__init__(self)
        self.thread_id = thread_id
        self.thread_nm = thread_nm
        self.set_str = set_str
        self.lower = lower
        self.upper = upper

    def run(self):
        print ("Starting " + self.thread_nm)
        download(self.thread_nm, self.set_str, self.lower, self.upper)
        print ("Exiting " + self.thread_nm)

def download(thread_nm, set_str, lower, upper):
    data = json.load(open(set_str + '.json'))

    t = time.time()
    
    for i in range(lower, upper):
        if exitFlag:
            thread_nm.exit()

        response = requests.get(data['images'][i]['url'], timeout = 5, stream = True)
        
        with open('data/'+set_str+'_images/'+str(data['images'][i]['imageId'])+'.jpeg', 'wb') as out_file:
            shutil.copyfileobj(response.raw, out_file)
        
        if i % 1000 == 0:
            t_diff = round(time.time() - t, 2)
            t = time.time()
            print('{0} - {1} - {2} - {3}s - {4}'.format(str(datetime.datetime.now()), thread_nm, set_str, t_diff, i))
        
        del response

# %%
thread1 = my_thread(1, 'Thread-1', 'test', 0, 8000)
thread2 = my_thread(2, 'Thread-2', 'test', 8000, 16000)
thread3 = my_thread(3, 'Thread-3', 'test', 16000, 24000)
thread4 = my_thread(4, 'Thread-4', 'test', 24000, 32000)
thread5 = my_thread(5, 'Thread-5', 'test', 32000, 40000)
thread1.start()
thread2.start()
thread3.start()
thread4.start()
thread5.start()
thread1.join()
thread2.join()
thread3.join()
thread4.join()
thread5.join()
print ("Exiting Main Thread.")
# Out:
# Starting Thread-1
# Starting Thread-2
# Starting Thread-3
# Starting Thread-4
# Starting Thread-5
# 2018-07-21 00:46:25.519961 - Thread-1 - test - 0.67s - 0
# 2018-07-21 00:46:25.641292 - Thread-2 - test - 0.79s - 8000
# 2018-07-21 00:46:25.965684 - Thread-3 - test - 1.14s - 16000
# 2018-07-21 00:46:25.975105 - Thread-4 - test - 1.1s - 24000
# 2018-07-21 00:46:26.020269 - Thread-5 - test - 1.14s - 32000
# 2018-07-21 00:50:41.280110 - Thread-2 - test - 255.64s - 9000
# 2018-07-21 00:52:00.435192 - Thread-1 - test - 334.92s - 1000
# 2018-07-21 00:55:02.923814 - Thread-5 - test - 516.9s - 33000
# 2018-07-21 00:55:13.283898 - Thread-3 - test - 527.32s - 17000
# 2018-07-21 00:55:32.617427 - Thread-2 - test - 291.34s - 10000
# 2018-07-21 00:55:34.622470 - Thread-4 - test - 548.65s - 25000
# 2018-07-21 00:58:45.518661 - Thread-1 - test - 405.08s - 2000
# 2018-07-21 01:03:37.804470 - Thread-3 - test - 504.52s - 18000
# 2018-07-21 01:03:48.776210 - Thread-5 - test - 525.85s - 34000
# 2018-07-21 01:04:17.623764 - Thread-1 - test - 332.11s - 3000
# 2018-07-21 01:04:19.512542 - Thread-2 - test - 526.9s - 11000
# 2018-07-21 01:06:07.594916 - Thread-4 - test - 632.97s - 26000
# 2018-07-21 01:11:57.107863 - Thread-1 - test - 459.48s - 4000
# 2018-07-21 01:12:40.836490 - Thread-3 - test - 543.03s - 19000
# 2018-07-21 01:13:17.911265 - Thread-2 - test - 538.4s - 12000
# 2018-07-21 01:14:20.447160 - Thread-5 - test - 631.67s - 35000
# 2018-07-21 01:16:44.328140 - Thread-4 - test - 636.73s - 27000
# 2018-07-21 01:19:19.512026 - Thread-1 - test - 442.4s - 5000
# 2018-07-21 01:21:22.675664 - Thread-3 - test - 521.84s - 20000
# 2018-07-21 01:21:42.721831 - Thread-2 - test - 504.81s - 13000
# 2018-07-21 01:25:00.465076 - Thread-5 - test - 640.02s - 36000
# 2018-07-21 01:26:49.258444 - Thread-1 - test - 449.75s - 6000
# 2018-07-21 01:27:09.744628 - Thread-4 - test - 625.42s - 28000
# 2018-07-21 01:29:55.317548 - Thread-3 - test - 512.64s - 21000
# 2018-07-21 01:30:28.381486 - Thread-2 - test - 525.66s - 14000
# 2018-07-21 01:30:58.353063 - Thread-1 - test - 249.09s - 7000
# 2018-07-21 01:35:20.525627 - Thread-5 - test - 620.06s - 37000
# Exiting Thread-1
# 2018-07-21 01:37:42.360938 - Thread-4 - test - 632.62s - 29000
# 2018-07-21 01:38:26.293228 - Thread-3 - test - 510.98s - 22000
# 2018-07-21 01:39:00.093280 - Thread-2 - test - 511.71s - 15000
# Exception in thread Thread-5:
# Traceback (most recent call last):
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 387, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 383, in _make_request
#     httplib_response = conn.getresponse()
#   File "/home/parmeet/anaconda3/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/home/parmeet/anaconda3/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/home/parmeet/anaconda3/lib/python3.6/http/client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/home/parmeet/anaconda3/lib/python3.6/socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py", line 294, in recv_into
#     raise timeout('The read operation timed out')
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/requests/adapters.py", line 440, in send
#     timeout=timeout
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 639, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py", line 357, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/packages/six.py", line 686, in reraise
#     raise value
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 601, in urlopen
#     chunked=chunked)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 389, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 309, in _raise_timeout
#     raise ReadTimeoutError(self, url, "Read timed out. (read timeout=%s)" % timeout_value)
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='contestimg.wish.com', port=443): Read timed out. (read timeout=5)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/parmeet/anaconda3/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "<ipython-input-1-5d33b6e2a57e>", line 16, in run
#     download(self.thread_nm, self.set_str, self.lower, self.upper)
#   File "<ipython-input-1-5d33b6e2a57e>", line 28, in download
#     response = requests.get(data['images'][i]['url'], timeout = 5, stream = True)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/requests/api.py", line 72, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/requests/api.py", line 58, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/requests/sessions.py", line 508, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/requests/sessions.py", line 618, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/requests/adapters.py", line 521, in send
#     raise ReadTimeout(e, request=request)
# requests.exceptions.ReadTimeout: HTTPSConnectionPool(host='contestimg.wish.com', port=443): Read timed out. (read timeout=5)
#
# Exception in thread Thread-6:
# Traceback (most recent call last):
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 387, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 383, in _make_request
#     httplib_response = conn.getresponse()
#   File "/home/parmeet/anaconda3/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/home/parmeet/anaconda3/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/home/parmeet/anaconda3/lib/python3.6/http/client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/home/parmeet/anaconda3/lib/python3.6/socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py", line 294, in recv_into
#     raise timeout('The read operation timed out')
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/requests/adapters.py", line 440, in send
#     timeout=timeout
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 639, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py", line 357, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/packages/six.py", line 686, in reraise
#     raise value
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 601, in urlopen
#     chunked=chunked)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 389, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 309, in _raise_timeout
#     raise ReadTimeoutError(self, url, "Read timed out. (read timeout=%s)" % timeout_value)
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='contestimg.wish.com', port=443): Read timed out. (read timeout=5)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/parmeet/anaconda3/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "<ipython-input-1-5d33b6e2a57e>", line 16, in run
#     download(self.thread_nm, self.set_str, self.lower, self.upper)
#   File "<ipython-input-1-5d33b6e2a57e>", line 28, in download
#     response = requests.get(data['images'][i]['url'], timeout = 5, stream = True)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/requests/api.py", line 72, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/requests/api.py", line 58, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/requests/sessions.py", line 508, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/requests/sessions.py", line 618, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/requests/adapters.py", line 521, in send
#     raise ReadTimeout(e, request=request)
# requests.exceptions.ReadTimeout: HTTPSConnectionPool(host='contestimg.wish.com', port=443): Read timed out. (read timeout=5)
#
# Exception in thread Thread-7:
# Traceback (most recent call last):
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 387, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 383, in _make_request
#     httplib_response = conn.getresponse()
#   File "/home/parmeet/anaconda3/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/home/parmeet/anaconda3/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/home/parmeet/anaconda3/lib/python3.6/http/client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/home/parmeet/anaconda3/lib/python3.6/socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py", line 294, in recv_into
#     raise timeout('The read operation timed out')
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/requests/adapters.py", line 440, in send
#     timeout=timeout
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 639, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py", line 357, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/packages/six.py", line 686, in reraise
#     raise value
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 601, in urlopen
#     chunked=chunked)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 389, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 309, in _raise_timeout
#     raise ReadTimeoutError(self, url, "Read timed out. (read timeout=%s)" % timeout_value)
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='contestimg.wish.com', port=443): Read timed out. (read timeout=5)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/parmeet/anaconda3/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "<ipython-input-1-5d33b6e2a57e>", line 16, in run
#     download(self.thread_nm, self.set_str, self.lower, self.upper)
#   File "<ipython-input-1-5d33b6e2a57e>", line 28, in download
#     response = requests.get(data['images'][i]['url'], timeout = 5, stream = True)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/requests/api.py", line 72, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/requests/api.py", line 58, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/requests/sessions.py", line 508, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/requests/sessions.py", line 618, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/parmeet/anaconda3/lib/python3.6/site-packages/requests/adapters.py", line 521, in send
#     raise ReadTimeout(e, request=request)
# requests.exceptions.ReadTimeout: HTTPSConnectionPool(host='contestimg.wish.com', port=443): Read timed out. (read timeout=5)
# 2018-07-21 01:46:18.523176 - Thread-5 - test - 658.0s - 38000
# 2018-07-21 01:57:34.669294 - Thread-5 - test - 676.15s - 39000
# Exiting Main Thread.
# Exception in thread Thread-8:
# Traceback (most recent call last):
#   File "/home/parmeet/anaconda3/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "<ipython-input-1-5d33b6e2a57e>", line 16, in run
#     download(self.thread_nm, self.set_str, self.lower, self.upper)
#   File "<ipython-input-1-5d33b6e2a57e>", line 28, in download
#     response = requests.get(data['images'][i]['url'], timeout = 5, stream = True)
# IndexError: list index out of range
